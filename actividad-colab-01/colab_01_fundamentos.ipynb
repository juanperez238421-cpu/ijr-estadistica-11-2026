# %% [markdown]
# # Statistics 11 · Lab 01 · Python Basics → Data
# **39 guided minutes · approximately one 40-minute class period**
#
# This notebook mirrors the classroom web workspace. Work in order and replace **every `WRITE_HERE`** before running a checkpoint. Use **Shift + Enter** to run a cell.
#
# **Command roadmap:** variables and `=`, `print()`, `type()`, arithmetic operators, strings, lists, indexing, `len()`, `for`, `def`, `return`, `if/else`, CSV, and Pandas.
#
# <sub>Apoyo: primero comandos básicos de Python; después análisis de datos.</sub>

# %% [markdown]
# ## 0 · Runtime check
# Run this cell first. If it prints **Python is ready**, continue.

# %%
print('Python is ready')

# %% [markdown]
# ## A1 · Variables, `print()` and `type()` · target 5 min
# Store two values, inspect one type, add the variables, and keep the numeric result on the final line.
# <sub>Variable = nombre que guarda un valor.</sub>

# %%
# Replace every WRITE_HERE
a = WRITE_HERE
b = WRITE_HERE

print('type of a:', type(a))

result = WRITE_HERE
print(result)

# %% [markdown]
# ## A2 · Arithmetic operators · target 5 min
# Practice `+`, `-`, `*`, `/`, and `**` with the same two inputs.

# %%
a = 12
b = 5

sum_value = WRITE_HERE
difference = WRITE_HERE
product = WRITE_HERE
quotient = WRITE_HERE
power = WRITE_HERE

print('sum:', sum_value)
print('difference:', difference)
print('product:', product)
print('quotient:', quotient)
print('power:', power)
print(product)

# %% [markdown]
# ## A3 · Strings, lists, indexing and `len()` · target 4 min
# Create text, access the first and last list items, and let Python count the observations. Python starts list indexes at zero: use `numbers[0]` for the first item and `numbers[-1]` for the last item.
# <sub>Índice = posición; `len()` = cantidad de elementos.</sub>

# %%
label = WRITE_HERE
numbers = [12, 7, 15, 9, 11]

first = WRITE_HERE
last = WRITE_HERE
count = WRITE_HERE

print('label:', label)
print('list type:', type(numbers))
print('first / last:', first, last)
print(count)

# %% [markdown]
# ## A4 · `for` loop and accumulator · target 5 min
# Repeat one instruction for every list value and build the running total.
# <sub>`for` = repetir para cada elemento.</sub>

# %%
numbers = [12, 7, 15, 9, 11]
total = 0

for value in numbers:
    total = WRITE_HERE

print('minimum:', min(numbers))
print('maximum:', max(numbers))
print(total)

# %% [markdown]
# ## A5 · Create a function for the arithmetic mean · target 6 min
# Use `def`, a parameter, `sum()`, `len()`, division, `return`, and a function call.

# %%
def mean(values):
    total = WRITE_HERE
    count = WRITE_HERE
    return WRITE_HERE

numbers = [12, 7, 15, 9, 11]
mean_value = mean(numbers)
print(round(mean_value, 1))

# %% [markdown]
# ## A6 · Import Pandas and read a CSV · target 5 min
# Move from Python objects to a real table. Inspect rows, columns, data types, and shape.
# <sub>DataFrame = tabla de datos.</sub>

# %%
import pandas as pd

DATA_URL = 'https://juanperez238421-cpu.github.io/ijr-estadistica-11-2026/actividad-colab-01/data.csv'
df = WRITE_HERE
preview = WRITE_HERE

print(preview)
print('columns:', df.columns.tolist())
print('data types:')
print(df.dtypes)

row_count = WRITE_HERE
print(row_count)

# %% [markdown]
# ## A7 · Select a column and summarize it · target 4 min
# Create a Series, calculate its mean, and inspect `describe()`.

# %%
import pandas as pd
DATA_URL = 'https://juanperez238421-cpu.github.io/ijr-estadistica-11-2026/actividad-colab-01/data.csv'
df = pd.read_csv(DATA_URL)

scores = WRITE_HERE
score_mean = WRITE_HERE
summary = WRITE_HERE

print(summary)
print(score_mean)

# %% [markdown]
# ## A8 · Boolean filter and basic `if / else` · target 5 min
# Build a `score >= 4` condition, filter rows, count them, and use the count in one decision.
# <sub>Condición = expresión verdadera o falsa.</sub>

# %%
import pandas as pd
DATA_URL = 'https://juanperez238421-cpu.github.io/ijr-estadistica-11-2026/actividad-colab-01/data.csv'
df = pd.read_csv(DATA_URL)

condition = WRITE_HERE
passed = WRITE_HERE
passed_count = WRITE_HERE

if passed_count >= 8:
    message = WRITE_HERE
else:
    message = 'Review needed'

print(message)
print(passed[['student_id', 'score']])
print(passed_count)

# %% [markdown]
# ## Optional exploration · after the 8 stages
# Only use these after the graded sequence is complete.
#
# - `17 // 5` and `17 % 5`
# - `numbers[1]` and `numbers[-2]`
# - `sum(numbers)` compared with the loop accumulator
# - `mean([10, 20, 30])`
# - `df.tail(2)`
# - `scores.min()`, `scores.max()`, `scores.median()`
# - `df['score'] >= 4.5`
