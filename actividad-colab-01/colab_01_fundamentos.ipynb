# %% [markdown]
# # Statistics 11 · Colab Lab 01
# **Python to Data — variables, lists, Pandas, and a first external CSV**
#
# Work in order. Run each code cell with **Shift + Enter**. After each checkpoint, return to the activity portal and submit the printed result. Mistakes are allowed: edit the code and run it again.

# %% [markdown]
# ## 0. First run
# If the cell below prints `Colab is ready`, your notebook is running correctly.

# %%
print('Colab is ready')

# %% [markdown]
# ## Checkpoints 1–2 · Variables and operations

# %%
a = 12
b = 5
result = a + b
print(result)

# %%
product = a * b
print(product)

# %% [markdown]
# ## Checkpoints 3–5 · A list of numbers

# %%
numbers = [12, 7, 15, 9, 11]
print(len(numbers))

# %%
print(sum(numbers))

# %%
mean_value = sum(numbers) / len(numbers)
print(mean_value)

# %% [markdown]
# ## Checkpoints 6–8 · First external dataset
# Now we move from isolated numbers to a real table. The CSV is stored in the course repository.

# %%
import pandas as pd
url = 'https://juanperez238421-cpu.github.io/ijr-estadistica-11-2026/actividad-colab-01/data.csv'
df = pd.read_csv(url)
df.head()

# %%
print(df.shape[0])

# %%
print(df['score'].mean())

# %%
passed = df[df['score'] >= 4]
print(len(passed))

# %% [markdown]
# ## Optional exploration
# Try these after finishing the 8 checkpoints. They are not graded.
#
# - `df.describe()`
# - `df['hours_studied'].max()`
# - `df.sort_values('score', ascending=False)`
# - Change the filter from `>= 4` to `>= 5`.
